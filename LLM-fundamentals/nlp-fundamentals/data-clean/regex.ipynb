# %%
import re

# %%
my_folder = r"C:\Desktop\notes"
print(my_folder)
# Out:
# C:\Desktop\notes

# %%
result_search = re.search("pattern", r"string to contains pattern")

# %%
print(result_search)
# Out:
# <re.Match object; span=(19, 26), match='pattern'>

# %% [markdown]
# Sub function of re let you search for a specific text in a string and replace it with new content
# re.sub(pattern, replacement, string)

# %%
string = r"sara was able to help me find the items i need quickly"

# %%
new_string = re.sub("sara", "Sarah", string)
print(new_string)
# Out:
# Sarah was able to help me find the items i need quickly
